# %%
# %load_ext autoreload
# %autoreload 2
# %autosave 0
# Out:
# Autosave disabled

# %% [markdown]
# # ErgastF1
#
# Extract, transform, and load data from Ergast Formula 1 data.
# https://ergast.com/mrd/db

# %%
from etl import DATADIR, afew, ErgastF1
ZIPPATH = DATADIR / 'ergast/f1.zip'

# %%
f1 = ErgastF1(ZIPPATH)
f1.names
# Out:
# ['circuits.csv',
#  'constructor_results.csv',
#  'constructors.csv',
#  'constructor_standings.csv',
#  'driver.csv',
#  'driver_standings.csv',
#  'lap_times.csv',
#  'pit_stops.csv',
#  'qualifying.csv',
#  'races.csv',
#  'results.csv',
#  'seasons.csv',
#  'status.csv']

# %% [markdown]
# ## Series

# %%
f1.seasons.head()
# Out:
# 0    2009
# 1    2008
# 2    2007
# 3    2006
# 4    2005
# Name: year, dtype: int64

# %%
f1.status.head()
# Out:
# 1        Finished
# 2    Disqualified
# 3        Accident
# 4       Collision
# 5          Engine
# Name: status, dtype: object

# %% [markdown]
# ## DataFrames

# %%
afew(f1.circuits)
# Out:
# 74 rows
#              dtype  nulls
# ref         object      0
# circuit     object      0
# city        object      0
# country     object      0
# latitude   float64      0
# longitude  float64      0
#                ref                       circuit         city    country  \
# 55           reims                   Reims-Gueux        Reims     France
# 57         zeltweg                       Zeltweg       Styria    Austria
# 32       rodriguez  Autódromo Hermanos Rodríguez  Mexico City     Mexico
# 10  hockenheimring                Hockenheimring   Hockenheim    Germany
# 15      marina_bay     Marina Bay Street Circuit   Marina Bay  Singapore
#
#     latitude  longitude
# 55   49.2542    3.93083
# 57   47.2039   14.74780
# 32   19.4042  -99.09070
# 10   49.3278    8.56583
# 15    1.2914  103.86400

# %%
afew(f1.drivers)
# Out:
# 847 rows
#                    dtype  nulls
# ref               object      0
# number             int64      0
# code              object    757
# first             object      0
# last              object      0
# birthday  datetime64[ns]      0
# nation            object      0
#           ref  number code    first      last   birthday      nation
# 760     dusio       0  NaN    Piero     Dusio 1899-10-13     Italian
# 616    george       0  NaN    Elmer    George 1928-07-15    American
# 844   leclerc      16  LEC  Charles   Leclerc 1997-10-16  Monegasque
# 654  faulkner       0  NaN     Walt  Faulkner 1920-02-16    American
# 577     musso       0  NaN    Luigi     Musso 1924-07-28     Italian

# %%
afew(f1.driver_standings)
# Out:
# 32566 rows
#              dtype  nulls
# id_race      int64      0
# id_driver    int64      0
# points     float64      0
# pos          int64      0
# wins         int64      0
#        id_race  id_driver  points  pos  wins
# 7034       298         95    86.0    1     8
# 12911       57         34     0.0   22     0
# 53066      664        340     0.0   27     0
# 13047       63         34     0.0   23     0
# 21405      448        160     2.0   18     0

# %%
afew(f1.lap_times)
# Out:
# 472504 rows
#              dtype  nulls
# id_race      int64      0
# id_driver    int64      0
# lap          int64      0
# pos          int64      0
# seconds    float64      0
#         id_race  id_driver  lap  pos  seconds
# 274862       81         21   48    4   82.031
# 379836      354          1    1    5   85.071
# 233041      111          4   51    6   84.552
# 288919       57         27   28   17   98.826
# 383551      917         13    1    3   81.964

# %%
afew(f1.pit_stops)
# Out:
# 7436 rows
#                      dtype  nulls
# id_race              int64      0
# id_driver            int64      0
# stop                 int64      0
# lap                  int64      0
# duration           float64      0
# time       timedelta64[ns]      0
#       id_race  id_driver  stop  lap  duration     time
# 1722      871        808     2   26    21.180 14:59:52
# 1312      863        815     2   21    23.428 15:39:34
# 6280      990        839     1   15    24.719 18:39:12
# 1140      860         18     2   36    22.837 17:59:44
# 1300      863        818     1   10    22.763 15:20:50

# %%
afew(f1.qualifying)
# Out:
# 8354 rows
#              dtype  nulls
# id_race      int64      0
# id_driver    int64      0
# id_team      int64      0
# number       int64      0
# pos          int64      0
# q1         float64    134
# q2         float64   4094
# q3         float64   5770
# best       float64    134
#       id_race  id_driver  id_team  number  pos       q1       q2  q3     best
# 4964      859        816      166      25   23  1081.14      NaN NaN  1081.14
# 3753      354         15      205      18   20  1395.00      NaN NaN  1395.00
# 1293       84         33       17      18   15  1902.60      NaN NaN  1902.60
# 1346       87         15        7      16    8   842.46      NaN NaN   842.46
# 4516       75         40       18      20   16  1278.36  1407.18 NaN  1278.36

# %%
afew(f1.races)
# Out:
# 1040 rows
#                       dtype  nulls
# season                int64      0
# round                 int64      0
# id_circuit            int64      0
# race                 object      0
# date         datetime64[ns]      0
# time        timedelta64[ns]    732
#      season  round  id_circuit                      race       date     time
# 51     2007     16          17        Chinese Grand Prix 2007-10-07 06:00:00
# 383    1988     12          14        Italian Grand Prix 1988-09-11      NaT
# 66     2006     14           5        Turkish Grand Prix 2006-08-27 15:00:00
# 99     2004     10           8         French Grand Prix 2004-07-04      NaT
# 736    1962      8          46  United States Grand Prix 1962-10-07      NaT

# %%
afew(f1.results)
# Out:
# 24620 rows
#                dtype  nulls
# id_race        int64      0
# id_driver      int64      0
# id_team        int64      0
# number         int64      0
# grid           int64      0
# pos            int64      0
# order          int64      0
# points       float64      0
# laps           int64      0
# fastlap        int64      0
# rank           int64      0
# fastlap_sec  float64  18398
# fastlap_kph  float64  18398
# id_status      int64      0
# sec          float64  18220
#        id_race  id_driver  id_team  number  grid  pos  order  points  laps  \
# 10698      453        137       34       5    20    0     15     0.0    51
# 2739       149         56       19      18    12    7      7     0.0    67
# 6644       310         95        3       5     2    2      2     6.0    67
# 11238      472        152       51      23     3    0     20     0.0     4
# 24517     1025        826        5      26    19   12     12     0.0    53
#
#        fastlap  rank  fastlap_sec  fastlap_kph  id_status       sec
# 10698        0     0          NaN          NaN         37       NaN
# 2739         0     0          NaN          NaN          1  5448.922
# 6644         0     0          NaN          NaN          1  5393.541
# 11238        0     0          NaN          NaN         86       NaN
# 24517       52     9      2353.68      214.325          1  5681.488

# %%
afew(f1.teams)
# Out:
# 209 rows
#          dtype  nulls
# ref     object      0
# team    object      0
# nation  object      0
#                  ref             team    nation
# 168      cooper-osca      Cooper-OSCA   British
# 169  cooper-borgward  Cooper-Borgward   British
# 59              wolf             Wolf  Canadian
# 209            manor   Manor Marussia   British
# 206         marussia         Marussia   Russian

# %%
afew(f1.team_results)
# Out:
# 11560 rows
#            dtype  nulls
# id_race    int64      0
# id_team    int64      0
# points   float64      0
# dsq         bool      0
#        id_race  id_team  points    dsq
# 3900         8        2     0.0  False
# 2388       241        1     0.0  False
# 14369      861        1    15.0  False
# 1443       155       21     0.0  False
# 2838       276       27     4.0  False

# %%
afew(f1.team_standings)
# Out:
# 12316 rows
#            dtype  nulls
# id_race    int64      0
# id_team    int64      0
# points   float64      0
# pos        int64      0
# wins       int64      0
#        id_race  id_team  points  pos  wins
# 25423      217       24     6.0    9     0
# 24936      860      208     6.0    5     0
# 20373      700      185     0.0   10     0
# 21879      606        6     6.0    4     0
# 20376      701       11     1.0    7     0
